# %%
from huggingface_hub import hf_hub_download
from pathlib import Path
import json

# Load HF token 
with open("secrets.json", "r") as f:
    HF_TOKEN = json.load(f)["HF_TOKEN"]

REPO = "unsloth/Llama-3.2-1B-Instruct-GGUF"

MODELS = [
    "Llama-3.2-1B-Instruct-Q2_K.gguf",
    "Llama-3.2-1B-Instruct-Q4_K_M.gguf",
]

Path("models").mkdir(exist_ok=True)

for model in MODELS:
    print(f"Downloading {model}")

    hf_hub_download(
        repo_id=REPO,
        filename=model,
        local_dir="models",
        token=HF_TOKEN,
    )

print("Done")
# Out:
# Downloading Llama-3.2-1B-Instruct-Q2_K.gguf
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 21
#      17
#      18 for model in MODELS:
#      19     print(f"Downloading {model}")
#      20
# ---> 21     hf_hub_download(
#      22         repo_id=REPO,
#      23         filename=model,
#      24         local_dir="models",
#
# File ~\Desktop\Capstone in ML\Capstone Project\Lib\site-packages\huggingface_hub\utils\_validators.py:91, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      87         validate_repo_id(arg_value)
#      89 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 91 return fn(*args, **kwargs)
#
# File ~\Desktop\Capstone in ML\Capstone Project\Lib\site-packages\huggingface_hub\utils\_http.py:266, in flag_as_download_call.<locals>._inner(*args, **kwargs)
#     264 token = _IS_DOWNLOAD_CALL.set(True)
#     265 try:
# --> 266     return fn(*args, **kwargs)
#     267 finally:
#     268     _IS_DOWNLOAD_CALL.reset(token)
#
# File ~\Desktop\Capstone in ML\Capstone Project\Lib\site-packages\huggingface_hub\file_download.py:1022, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, etag_timeout, token, local_files_only, headers, endpoint, tqdm_class, dry_run)
#    1013 hf_headers = build_hf_headers(
#    1014     token=token,
#    1015     library_name=library_name,
#    (...)   1018     headers=headers,
#    1019 )
#    1021 if local_dir is not None:
# -> 1022     return _hf_hub_download_to_local_dir(
#    1023         # Destination
#    1024         local_dir=local_dir,
#    1025         # File info
#    1026         repo_id=repo_id,
#    1027         repo_type=repo_type,
#    1028         filename=filename,
#    1029         revision=revision,
#    1030         # HTTP info
#    1031         endpoint=endpoint,
#    1032         etag_timeout=etag_timeout,
#    1033         headers=hf_headers,
#    1034         token=token,
#    1035         # Additional options
#    1036         cache_dir=cache_dir,
#    1037         force_download=force_download,
#    1038         local_files_only=local_files_only,
#    1039         tqdm_class=tqdm_class,
#    1040         dry_run=dry_run,
#    1041     )
#    1042 else:
#    1043     return _hf_hub_download_to_cache_dir(
#    1044         # Destination
#    1045         cache_dir=cache_dir,
#    (...)   1060         dry_run=dry_run,
#    1061     )
#
# File ~\Desktop\Capstone in ML\Capstone Project\Lib\site-packages\huggingface_hub\file_download.py:1362, in _hf_hub_download_to_local_dir(local_dir, repo_id, repo_type, filename, revision, endpoint, etag_timeout, headers, token, cache_dir, force_download, local_files_only, tqdm_class, dry_run)
#    1358 # Local file doesn't exist or commit_hash doesn't match => we need the etag
#    1359 # - Xet file => might be cached in /tree listing
#    1360 # - otherwise => HEAD /resolve call
#    1361 tree_cache_folder = tree_cache_folder_for_local_dir(str(local_dir))
# -> 1362 (url_to_download, etag, commit_hash, expected_size, xet_file_data, head_call_error) = _get_metadata_or_catch_error(
#    1363     repo_id=repo_id,
#    1364     filename=filename,
#    1365     repo_type=repo_type,
#    1366     revision=revision,
#    1367     endpoint=endpoint,
#    1368     etag_timeout=etag_timeout,
#    1369     headers=headers,
#    1370     token=token,
#    1371     local_files_only=local_files_only,
#    1372     tree_cache_folder=tree_cache_folder,
#    1373 )
#    1375 if head_call_error is not None:
#    1376     # No HEAD call but local file exists => default to local file
#    1377     if paths.file_path.is_file():
#
# File ~\Desktop\Capstone in ML\Capstone Project\Lib\site-packages\huggingface_hub\file_download.py:1758, in _get_metadata_or_catch_error(repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, token, local_files_only, relative_filename, storage_folder, retry_on_errors, tree_cache_folder)
#    1756 try:
#    1757     try:
# -> 1758         metadata = get_hf_file_metadata(
#    1759             url=url,
#    1760             timeout=etag_timeout,
#    1761             headers=headers,
#    1762             token=token,
#    1763             endpoint=endpoint,
#    1764             retry_on_errors=retry_on_errors,
#    1765         )
#    1766     except RemoteEntryNotFoundError as http_error:
#    1767         if storage_folder is not None and relative_filename is not None:
#    1768             # Cache the non-existence of the file
#
# File ~\Desktop\Capstone in ML\Capstone Project\Lib\site-packages\huggingface_hub\utils\_validators.py:91, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      87         validate_repo_id(arg_value)
#      89 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 91 return fn(*args, **kwargs)
#
# File ~\Desktop\Capstone in ML\Capstone Project\Lib\site-packages\huggingface_hub\file_download.py:1665, in get_hf_file_metadata(url, token, timeout, library_name, library_version, user_agent, headers, endpoint, retry_on_errors)
#    1662 hf_headers["Accept-Encoding"] = "identity"  # prevent any compression => we want to know the real size of the file
#    1664 # Retrieve metadata
# -> 1665 response = _httpx_follow_hub_redirects_with_backoff(
#    1666     method="HEAD", url=url, headers=hf_headers, timeout=timeout, retry_on_errors=retry_on_errors
#    1667 )
#    1668 hf_raise_for_status(response)
#    1670 # Return
#
# File ~\Desktop\Capstone in ML\Capstone Project\Lib\site-packages\huggingface_hub\utils\_http.py:754, in _httpx_follow_hub_redirects_with_backoff(method, url, retry_on_errors, **httpx_kwargs)
#     749 no_retry_kwargs: dict[str, Any] = (
#     750     {} if retry_on_errors else {"retry_on_exceptions": (), "retry_on_status_codes": ()}
#     751 )
#     753 for _ in range(_MAX_REDIRECTS):
# --> 754     response = http_backoff(
#     755         method=method,
#     756         url=url,
#     757         **httpx_kwargs,
#     758         follow_redirects=False,
#     759         **no_retry_kwargs,
#     760     )
#     761     hf_raise_for_status(response)
#     763     if not response.has_redirect_location:
#
# File ~\Desktop\Capstone in ML\Capstone Project\Lib\site-packages\huggingface_hub\utils\_http.py:627, in http_backoff(method, url, max_retries, base_wait_time, max_wait_time, retry_on_exceptions, retry_on_status_codes, **kwargs)
#     562 def http_backoff(
#     563     method: HTTP_METHOD_T,
#     564     url: str,
#    (...)    571     **kwargs,
#     572 ) -> httpx.Response:
#     573     """Wrapper around httpx to retry calls on an endpoint, with exponential backoff.
#     574
#     575     Endpoint call is retried on exceptions (ex: connection timeout, proxy error,...)
#    (...)    625     > issue on [Github](https://github.com/huggingface/huggingface_hub).
#     626     """
# --> 627     return next(
#     628         _http_backoff_base(
#     629             method=method,
#     630             url=url,
#     631             max_retries=max_retries,
#     632             base_wait_time=base_wait_time,
#     633             max_wait_time=max_wait_time,
#     634             retry_on_exceptions=retry_on_exceptions,
#     635             retry_on_status_codes=retry_on_status_codes,
#     636             stream=False,
#     637             **kwargs,
#     638         )
#     639     )
#
# File ~\Desktop\Capstone in ML\Capstone Project\Lib\site-packages\huggingface_hub\utils\_http.py:535, in _http_backoff_base(method, url, max_retries, base_wait_time, max_wait_time, retry_on_exceptions, retry_on_status_codes, stream, **kwargs)
#     533             return
#     534 else:
# --> 535     response = client.request(method=method, url=url, **kwargs)
#     536     if not _should_retry(response):
#     537         yield response
#
# File ~\Desktop\Capstone in ML\Capstone Project\Lib\site-packages\httpx\_client.py:825, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     810     warnings.warn(message, DeprecationWarning, stacklevel=2)
#     812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#    (...)    823     extensions=extensions,
#     824 )
# --> 825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~\Desktop\Capstone in ML\Capstone Project\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~\Desktop\Capstone in ML\Capstone Project\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~\Desktop\Capstone in ML\Capstone Project\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~\Desktop\Capstone in ML\Capstone Project\Lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~\Desktop\Capstone in ML\Capstone Project\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~\Desktop\Capstone in ML\Capstone Project\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~\Desktop\Capstone in ML\Capstone Project\Lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~\Desktop\Capstone in ML\Capstone Project\Lib\site-packages\httpcore\_sync\connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~\Desktop\Capstone in ML\Capstone Project\Lib\site-packages\httpcore\_sync\http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~\Desktop\Capstone in ML\Capstone Project\Lib\site-packages\httpcore\_sync\http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~\Desktop\Capstone in ML\Capstone Project\Lib\site-packages\httpcore\_sync\http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~\Desktop\Capstone in ML\Capstone Project\Lib\site-packages\httpcore\_sync\http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~\Desktop\Capstone in ML\Capstone Project\Lib\site-packages\httpcore\_backends\sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File ~\miniconda3\Lib\ssl.py:1234, in SSLSocket.recv(self, buflen, flags)
#    1230     if flags != 0:
#    1231         raise ValueError(
#    1232             "non-zero flags not allowed in calls to recv() on %s" %
#    1233             self.__class__)
# -> 1234     return self.read(buflen)
#    1235 else:
#    1236     return super().recv(buflen, flags)
#
# File ~\miniconda3\Lib\ssl.py:1107, in SSLSocket.read(self, len, buffer)
#    1105         return self._sslobj.read(len, buffer)
#    1106     else:
# -> 1107         return self._sslobj.read(len)
#    1108 except SSLError as x:
#    1109     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:
